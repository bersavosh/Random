# %%
import numpy as np
from astropy.io import fits,ascii
import matplotlib.pyplot as plt
from specutils.io import read_fits
# %matplotlib notebook

# %%
maxi_spec = read_fits.read_fits_spectrum1d('./real_maxi_c.fits')

# %%
plt.plot(maxi_spec[0][0].dispersion,maxi_spec[0][0].flux,lw=0.4)
plt.
#plt.plot(maxi_spec[0][1].dispersion,maxi_spec[0][1].flux,lw=0.4)
#plt.plot(maxi_spec[0][2].dispersion,maxi_spec[0][2].flux,lw=0.4)
#plt.plot(maxi_spec[0][3].dispersion,maxi_spec[0][3].flux,lw=0.4)
plt.yscale('log')
plt.gca().invert_xaxis()
# Out:
# <img src="data:image/png;base64,..." width="885">

# %%
fits.open('./real_maxi_c.fits')[0].header['BANDID1']
# Out:
# 'spectrum - background fit, weights variance, clean yes'
